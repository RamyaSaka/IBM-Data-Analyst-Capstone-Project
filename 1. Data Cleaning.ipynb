# %% [markdown]
# ## Exploring Dataset

# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell    # Used to execute all commands in a cell
InteractiveShell.ast_node_interactivity = "all"
#InteractiveShell.ast_node_interactivity = "last_expr"

# %% [markdown]
# ### a. Loading dataset

# %%
# Reading the dataset

dataset_url=('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv')
df=pd.read_csv(dataset_url)                            # Reading dataset using read_csv()

# %% [markdown]
# ### b. Exploring the dataset

# %%
# Displyaing first five rows of the data set

df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
#Obtaining no of rows and columns in the dataset.

df.shape                            # (rows,columns)
df.shape[0]                         # rows
df.shape[1]                         # columns
# Out:
# (11552, 85)
# 11552
# 85

# %%
#Obtaining datatypes of all columns

df.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
#Obtaining unique values

df.nunique()                                          # Obtaining the count of unique values from all columns

df['Ethnicity'].nunique()                             # Obtaining the count of  unique values in ethnicity column
# Out:
# Respondent      11398
# MainBranch          2
# Hobbyist            2
# OpenSourcer         4
# OpenSource          3
#                 ...
# Sexuality           7
# Ethnicity          89
# Dependents          2
# SurveyLength        3
# SurveyEase          3
# Length: 85, dtype: int64
# 89

# %%
# Finding duplicates 

df.duplicated().sum()                            # Number of duplicated values
df[df.duplicated()]                              # duplicate rows
# Out:
# 154
# 154
#       Respondent                                         MainBranch Hobbyist  \
# 1168        2339                     I am a developer by profession      Yes
# 1169        2342                     I am a developer by profession      Yes
# 1170        2343                     I am a developer by profession      Yes
# 1171        2344                     I am a developer by profession      Yes
# 1172        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
# ...

# %%
# Dropping duplicate values

df.drop_duplicates(inplace=True)
df.duplicated().sum()                                        # Verifying whether duplicate values are  dropped or not
df[df.duplicated()]
# Out:
# 0
# Empty DataFrame
# ...

# %% [markdown]
# ### Finding null values

# %%
#Finding null values in the dataframe

df.isnull()
# Out:
#        Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  \
# 0           False       False     False        False       False       False
# 1           False       False     False        False       False       False
# 2           False       False     False        False       False       False
# 3           False       False     False        False       False       False
# 4           False       False     False        False       False       False
# ...           ...         ...       ...          ...         ...         ...
# 11547       False       False     False        False       False       False
# 11548       False       False     False        False       False       False
# 11549       False       False     False        False       False       False
# 11550       False       False     False        False       False       False
# 11551       False       False     False        False       False       False
#
# ...

# %%
df.isnull().sum()                    #Obtaining the count of null values in the all columns

df['WorkLoc'].isnull().sum()         #Obtaining count of null values from work location column
df['Country'].isnull().sum()           #Obtaining count od null values from country column
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64
# 32
# 0

# %% [markdown]
# ## Imputing null values

# %%
df['WorkLoc'].value_counts()                             # Finding the value counts for Work Location column

df['WorkLoc'].value_counts().idxmax()                    # Finding the value that occurs frequently in work location column
# Out:
# WorkLoc
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: count, dtype: int64
# 'Office'

# %%
df['WorkLoc'].replace(np.nan,'Office',inplace=True)       # Replcaing null values in work location column with max occuring value

df['WorkLoc'].isnull().sum()                              # Verifying if imputation is successful
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %%
#There are two columns in the dataset that talk about compensation.

#One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).

#The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".

#This makes it difficult to compare the total compensation of the developers.

#So we are creating a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.

#This new column makes comparison of salaries easy.

# %%
df['CompFreq'].unique()          # Listing out categories of column CompFreq
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %%
#Replcaing values in CompFreq column

df['CompFreq'].replace('Yearly',1,inplace=True)
df['CompFreq'].replace(to_replace='Monthly',value=12,inplace=True)
df['CompFreq'].replace(to_replace='Weekly',value=52,inplace=True)

# %%
df['CompFreq'].unique()
# Out:
# array([ 1., 12., 52., nan])

# %%
df['CompFreq'].value_counts()
# Out:
# CompFreq
# 1.0     6073
# 12.0    4788
# 52.0     331
# Name: count, dtype: int64

# %%
df['NormalizedAnnualCompensation']=df['CompTotal']*df['CompFreq']
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df['NormalizedAnnualCompensation'].mean()
df['NormalizedAnnualCompensation'].median()
# Out:
# 6136037.047340074
# 100000.0
